# %% [markdown]
# <img src="./images/logo1.png">

# %% [markdown]
# # <center> Introducción al Análisis de Datos con R

# %%
library("ggplot2")
library("tidyverse")
options(repr.plot.width=16, repr.plot.height=8)

# %% [markdown]
# # Elementos esenciales
# - **Data** : El conjunto de datos graficado.
# - **Aesthetic** : Los ejes o de nuestro gráfico, además del color, fill, shape, entre otros.
# - **Geometries** : Los elementos visuales para nuestros datos.
# - **Themes** :
# - **Statistics** :
# - **Coordinates**:
# - **Facets** :

# %%
# exploración de la base  
str(diamonds)
# Out:
# tibble [53,940 x 10] (S3: tbl_df/tbl/data.frame)
#  $ carat  : num [1:53940] 0.23 0.21 0.23 0.29 0.31 0.24 0.24 0.26 0.22 0.23 ...
#  $ cut    : Ord.factor w/ 5 levels "Fair"<"Good"<..: 5 4 2 4 2 3 3 3 1 3 ...
#  $ color  : Ord.factor w/ 7 levels "D"<"E"<"F"<"G"<..: 2 2 2 6 7 7 6 5 2 5 ...
#  $ clarity: Ord.factor w/ 8 levels "I1"<"SI2"<"SI1"<..: 2 3 5 4 2 6 7 3 4 5 ...
#  $ depth  : num [1:53940] 61.5 59.8 56.9 62.4 63.3 62.8 62.3 61.9 65.1 59.4 ...
#  $ table  : num [1:53940] 55 61 65 58 58 57 57 55 61 61 ...
#  $ price  : int [1:53940] 326 326 327 334 335 336 336 337 337 338 ...
#  $ x      : num [1:53940] 3.95 3.89 4.05 4.2 4.34 3.94 3.95 4.07 3.87 4 ...
#  $ y      : num [1:53940] 3.98 3.84 4.07 4.23 4.35 3.96 3.98 4.11 3.78 4.05 ...
#  $ z      : num [1:53940] 2.43 2.31 2.31 2.63 2.75 2.48 2.47 2.53 2.49 2.39 ...

# %%
# estructura básica de un gráfico
ggplot(base, aes(x, y)) +
geom_point()
# Out:
# Error in ggplot(base, aes(x, y)): objeto 'base' no encontrado
# Traceback:
#
# 1. ggplot(base, aes(x, y))

# %% [markdown]
# ## Datos de diamantes

# %% [markdown]
# | Variable | Descripción |
# |:---------|:--------------|
# | carat   | Peso del diamante (0.2-5.01) |
# | cut     | Calidad del corte (Fair, Good, very Good, Premium, Ideal) |
# | color   | Color del diamante |
# | clarity | Medición de claridad del diamante (l1 (lowest) hasta IF (best)) |
# | x       | Largo en mm |
# | y       | Ancho en mm |
# | z       | Depth en mm |
# | depth   | total depth percentage |
# | table   | anchura de la parte superior del diamante en relación con el punto más ancho (43-95) |

# %%
head(diamonds)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %% [markdown]
# El aesthetics acepta:
# - (Esenciales) : x, y
# - (Optionales) : <span style="color:blue">color</span> (contorno), <span style="color:blue">fill</span> (relleno), <span style="color:blue">shape</span> (forma), <span style="color:blue">size</span> (tamaño), <span style="color:blue">alpha</span>  (transparencia), <span style="color:blue">stroke</span>.

# %% [markdown]
# ## Grafico 1 : Peso vs precio (¿A mayor peso mayor precio?)

# %%
# Gráfico de puntos
p1 <- ggplot(diamonds, aes(x=carat, y=price)) +
  # definimos la geometría (gráfico de puntos)
  geom_point() +
  # título del eje x
  xlab('Carat') +
  # título del eje y
  ylab('Price') +
  # titulo principal
  ggtitle('Carat vs price')

p1
# Out:
# plot without title

# %% [markdown]
# ## Relación peso vs precio visto por corte

# %%
# Mismo gráfico pero identificando el corte por color
p2 <- ggplot(diamonds, aes(x=carat, y=price, color=cut)) +
  # definimos la geometría (gráfico de puntos)
  geom_point() +
  # título del eje x
  xlab('Carat') +
  # título del eje y
  ylab('Price') +
  # titulo principal
  ggtitle('Carat vs price') +
  # Se modifica el tamaño de fuente  de leyenda de ejes y titulo
  theme(axis.text=element_text(size=12), # modifica el tamaño de la fuente de los ejes x, y
        axis.title=element_text(size=20), # modifica el tamaño de la fuente de eiquetas de los ejes x, y
        plot.title = element_text(hjust = 0, size=24, color="blue"), # modifica el posición, tamaño y color del título
        legend.position="bottom", # mueve la posición de la leyenda a la parte inferior
        legend.box = "horizontal") # Si existen muchas legendas las pone de forma horizantal

p2
# Out:
# plot without title

# %% [markdown]
# ## Relación peso vs precio visto por claridad

# %%
# Mismo gráfico pero identificando la claridad por color
# definimos nuestros colores 
col <- c("#999999", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7")
# graficamos
# Mismo gráfico pero identificando el corte por color
p3 <- ggplot(diamonds, aes(x=carat, y=price, color=clarity)) +
  # definimos la geometría (gráfico de puntos)
  geom_point() + 
  # título del eje x
  xlab('Carat') +
  # título del eje y
  ylab('Price') +
  # cambio de limite de eje x
  xlim(0,5.2) +
  # titulo principal
  ggtitle('Carat vs price') +
  # Se modifica el tamaño de fuente  de leyenda de ejes y titulo
  theme(axis.text=element_text(size=12), # modifica el tamaño de la fuente de los ejes x, y
        axis.title=element_text(size=20),# modifica el tamaño de la fuente de eiquetas de los ejes x, y
        plot.title = element_text(hjust = 0, size=24, color="blue"), # modifica el posición, tamaño y color del título
        legend.position="bottom",    # mueve la posición de la leyenda a la parte inferior
        legend.box = "horizontal") + # Si existen muchas legendas las pone de forma horizantal
  # colores definidos manualmente
  scale_colour_manual(values=col)

p3
# Out:
# plot without title

# %% [markdown]
# #  FACETS

# %% [markdown]
# ## Relación peso vs precio visto por corte (un gráfico por corte)

# %%
# facet_wrap (separa gráficos en subconjuntos)
p4 <- ggplot(diamonds, aes(x=carat, y=price, color=cut)) +
  # definimos la geometría (gráfico de puntos)
  geom_point() +
  # recta suavizada
  geom_smooth() +
  # título del eje x
  xlab('Carat') +
  # título del eje y
  ylab('Price') +
  # cambio de limite de eje x
  xlim(0,5.2) +
  # titulo principal
  ggtitle('Carat vs price') +
  # Se modifica el tamaño de fuente  de leyenda de ejes y titulo
  theme(axis.text=element_text(size=12), # modifica el tamaño de la fuente de los ejes x, y
        axis.title=element_text(size=20), # modifica el tamaño de la fuente de eiquetas de los ejes x, y
        plot.title = element_text(hjust = 0, size=24, color="blue"), # modifica el posición, tamaño y color del título
        legend.position="bottom",    # mueve la posición de la leyenda a la parte inferior
        legend.box = "horizontal") + # Si existen muchas legendas las pone de forma horizantal
  # separa un gráfico por la variable corte
  facet_wrap(~cut) 
p4
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# # Relación peso vs precio visto por corte y claridad (un gráfico por corte y claridad)

# %%
# Facet grid
p5 <- ggplot(diamonds, aes(x=carat, y=price, color=cut)) +
  # definimos la geometría (gráfico de puntos)
  geom_point() +
  # título del eje x
  xlab('Carat') +
  # título del eje y
  ylab('Price') +
  # cambio de limite de eje x
  xlim(0,5.2) +
  # titulo principal
  ggtitle('Carat vs price') +
  # Se modifica el tamaño de fuente  de leyenda de ejes y titulo
  theme(axis.text=element_text(size=12), # modifica el tamaño de la fuente de los ejes x, y
        axis.title=element_text(size=20),# modifica el tamaño de la fuente de eiquetas de los ejes x, y
        plot.title = element_text(hjust = 0, size=24, color="blue"), # modifica el posición, tamaño y color del título
        legend.position="bottom",    # mueve la posición de la leyenda a la parte inferior
        legend.box = "horizontal") + # Si existen muchas legendas las pone de forma horizantal
  # separa un gráfico por la variable corte
  facet_grid(cols=vars(cut), rows= vars(clarity), scales="free")

p5
# Out:
# plot without title

# %%
# para guardar nuestro gráfico
tiff('p2.tiff', units="cm", width=25, height=8, res=300)
p2
dev.off()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# png
#   2

# %% [markdown]
# # Tipos de geometrías
#
# |Name | Description |
# |----|----|
# | abline | Line, specified by slope and intercept |
# | area   | Area plots |
# | bar    | Bars, rectangles with bases on y-axis |
# | blank  | Blank, draws nothing |
# | boxplot | Box-and-whisker plot |
# | contour | Display contours of a 3d surface in 2d |
# | crossbar | Hollow bar with middle indicated by horizontal line |
# | density | Display a smooth density estimate |
# | density 2d | Contours from a 2d density estimate |
# | errorbar | Error bars |
# | histogram | Histogram |
# | hline | Line, horizontal |
# | interval | Base for all interval (range) geoms |
# | jitter | Points, jittered to reduce overplotting |
# | line  | Connect observations, in order of x value |
# | linerange | An interval represented by a vertical line
# | path | Connect observations, in original order |
# | point | Points, as for a scatterplot |
# | pointrange | An interval represented by a vertical line, with a point in the middle |
# | polygon | Polygon, a filled path |
# | quantile | Add quantile lines from a quantile regression |
# | ribbon | Ribbons, y range with continuous x values |
# | rug | Marginal rug plots |
# | segment | Single line segments |
# | smooth | Add a smoothed condition mean |
# | step | Connect observations by stairs |
# | text | Textual annotations |
# | tile | Tile plot as densely as possible, assuming that every tile  is the same size |
# | vline | Line, vertical |

# %% [markdown]
# ## Boxplot

# %%
# boxplot
p6 <- ggplot(diamonds, aes(x=cut, y=price, fill=cut)) +
    geom_boxplot(alpha=0.5) +
    facet_wrap(~clarity)
p6
# Out:
# plot without title

# %% [markdown]
# ## Histograma

# %% [markdown]
# ## ¿Cómo se distribuye el precio?

# %%
p7 <- ggplot(diamonds, aes(x=price)) +
    geom_histogram()
p7
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## Distribución del precio por claridad (un gráfico por claridad)

# %%
# histograma
p8 <- ggplot(diamonds, aes(x=price)) +
    geom_histogram(aes(y=..density.., fill=clarity), alpha=0.7, bins = 30) +
    geom_density(aes(fill=clarity, color=clarity), alpha=0.2) +
    facet_wrap(~clarity, scales="free") +
    theme(axis.text=element_text(size=12), # modifica el tamaño de la fuente de los ejes x, y
          axis.title=element_text(size=20), # modifica el tamaño de la fuente de eiquetas de los ejes x, y
          plot.title = element_text(hjust = 0, size=24, color="blue"), # modifica el posición, tamaño y color del título
          legend.position="bottom",    # mueve la posición de la leyenda a la parte inferior
          legend.box = "horizontal")
p8
# Out:
# plot without title

# %% [markdown]
# # Gráfico de puntos

# %% [markdown]
# ## Grálfico de el promedio de x contra el promedio del promedio del precio (price) por la variable corte (cut)

# %%
df01 <- diamonds  %>% 
    group_by(cut)  %>% 
    summarize(mean_x = mean(x), mean_price = mean(price))  %>% 
    ungroup()  %>% 
    arrange(desc(mean_price))

df01
# Out:
#   cut       mean_x   mean_price
# 1 Premium   5.973887 4584.258
# 2 Fair      6.246894 4358.758
# 3 Very Good 5.740696 3981.760
# 4 Good      5.838785 3928.864
# 5 Ideal     5.507451 3457.542

# %%
# gráfico de puntos
p9 <- ggplot(df01, aes(x=mean_x, y=mean_price, color=cut)) +
    geom_point() +
    geom_text(aes(label=cut, color=cut))
p9
# Out:
# plot without title

# %% [markdown]
# ## Gráfico de barras

# %% [markdown]
# ## Frecuencia de la variable corte (cut)

# %%
# gráfico de barras
p10 <- ggplot(diamonds, aes(x=cut)) +
    geom_bar( fill="steelblue") +
    coord_flip() + 
    #geom_text(aes(y=0,label=cut), hjust=-0.5 ,vjust=0.2, color="white", size=5)+
    theme_minimal() +
    theme(panel.grid.major = element_blank(),
          panel.grid.minor = element_blank(),
          axis.title.x=element_blank(),
          axis.text.x=element_blank(),
          axis.ticks.x=element_blank(),
          axis.text=element_text(size=14,color="steelblue",face="bold")) +
    labs(title = "",
         x = "", y = "") 
p10
# Out:
# plot without title

# %% [markdown]
# # Line plot

# %%
url <- 'https://raw.githubusercontent.com/JulioCesarMartinez-00/S1-Introduccion-a-R/main/Sesi%C3%B3n4%20Manejo%20de%20datos%20con%20R/datsets/df_DownJones.csv'

# %%
# lectura de datos
down <- read.csv(url) %>% 
    mutate(Date = as.Date(Date, "%Y-%m-%d"))

# %%
head(down, 4)
# Out:
#   Date       WMT      MRK      INTC     MSFT     MMM      AAPL     VZ
# 1 1990-01-03 5.890625 13.31250 1.093750 0.619792 20.34375 0.334821 25.57449
# 2 1990-01-04 5.859375 13.10417 1.117188 0.638021 20.50000 0.335938 24.59086
# 3 1990-01-05 5.796875 12.83333 1.109375 0.622396 20.15625 0.337054 24.02878
# 4 1990-01-08 5.875000 13.00000 1.125000 0.631944 20.68750 0.339286 24.22551
#   JNJ      KO       ... NKE      DIS      HD       TRV      RTX      AXP
# 1 7.515625 4.804688 ... 0.859375 9.515615 1.870370 15.09375 4.316787 9.076314
# 2 7.531250 4.781250 ... 0.841797 9.505339 1.882716 15.37500 4.306954 8.979757
# 3 7.453125 4.742188 ... 0.867188 9.536167 1.858025 15.31250 4.306954 8.883201
# 4 7.578125 4.843750 ... 0.863281 9.608099 1.839506 15.37500 4.326621 8.818830
#   CVX      JPM      XOM     BA
# 1 17.00000 10.33333 12.3750 21.00000
# 2 16.78125 10.37500 12.2500 20.91667
# 3 16.53125 10.41667 12.1875 20.62500
# 4 16.68750 10.41667 12.3750 20.87500

# %%
down_longer <- down %>% 
    pivot_longer(cols=WMT:BA, names_to='name', values_to='price') %>%
    mutate(price = as.numeric(price))

# %%
head(down_longer)
# Out:
#   Date       name price
# 1 1990-01-03 WMT   5.890625
# 2 1990-01-03 MRK  13.312500
# 3 1990-01-03 INTC  1.093750
# 4 1990-01-03 MSFT  0.619792
# 5 1990-01-03 MMM  20.343750
# 6 1990-01-03 AAPL  0.334821

# %%
p11 <- ggplot(down_longer, aes(x=Date, y=price, color=name)) +
    geom_line() 
p11
# Out:
# plot without title
